# %% [markdown]
# # Plotting PCA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading files

# %%
pca = pd.read_table("../05_PCA/plink_results_projected.sscore",sep="\t")
pca
# Out:
#      #FID      IID  ALLELE_CT  NAMED_ALLELE_DOSAGE_SUM   PC1_AVG   PC2_AVG  \
# 0       0  HG00403     219504                   219504  0.000644 -0.029750
# 1       0  HG00404     219504                   219504 -0.000492 -0.031018
# 2       0  HG00406     219504                   219504  0.006210 -0.034375
# 3       0  HG00407     219504                   219504  0.006786 -0.023931
# 4       0  HG00409     219504                   219504 -0.002363 -0.023160
# ..    ...      ...        ...                      ...       ...       ...
# 499     0  NA19087     219504                   219504 -0.075155  0.030773
# 500     0  NA19088     219504                   219504 -0.079479  0.034983
# 501     0  NA19089     219504                   219504 -0.083754  0.037050
# 502     0  NA19090     219504                   219504 -0.069719  0.028421
# 503     0  NA19091     219504                   219504 -0.077385  0.038104
#
#       PC3_AVG   PC4_AVG   PC5_AVG   PC6_AVG   PC7_AVG   PC8_AVG   PC9_AVG  \
# 0   -0.015150 -0.012238  0.022915  0.023541 -0.033705 -0.007513 -0.012540
# 1   -0.007642 -0.020500  0.028407 -0.008724  0.012335 -0.004921 -0.005570
# 2   -0.008986 -0.003351 -0.021756 -0.018243  0.003339 -0.007606 -0.034002
# 3   -0.007044 -0.004661  0.009854  0.000890  0.006796 -0.020050 -0.013187
# 4    0.032066  0.014556  0.023677  0.007048  0.012859  0.031961 -0.013063
# ..        ...       ...       ...       ...       ...       ...       ...
# 499 -0.012063 -0.020874 -0.009061  0.016212 -0.014142 -0.009302 -0.033492
# 500 -0.023635 -0.018341 -0.006770 -0.019187 -0.020756 -0.020069 -0.000052
# 501 -0.021951  0.030121 -0.041074 -0.019957  0.002440 -0.010965  0.014069
# 502 -0.014476  0.012602 -0.032481 -0.032686  0.023443  0.004380  0.006470
# 503 -0.017811  0.021642 -0.035877 -0.028448 -0.002518 -0.011106  0.003426
#
#      PC10_AVG
# 0    0.002717
# 1    0.024897
# 2    0.006411
# 3    0.035033
# 4    0.011022
# ..        ...
# 499 -0.018796
# 500  0.010113
# 501  0.021758
# 502 -0.018362
# 503 -0.003905
#
# [504 rows x 14 columns]

# %%
ped = pd.read_table("../01_Dataset/integrated_call_samples_v3.20130502.ALL.panel",sep="\t")
ped
# Out:
#        sample  pop super_pop  gender  Unnamed: 4  Unnamed: 5
# 0     HG00096  GBR       EUR    male         NaN         NaN
# 1     HG00097  GBR       EUR  female         NaN         NaN
# 2     HG00099  GBR       EUR  female         NaN         NaN
# 3     HG00100  GBR       EUR  female         NaN         NaN
# 4     HG00101  GBR       EUR    male         NaN         NaN
# ...       ...  ...       ...     ...         ...         ...
# 2499  NA21137  GIH       SAS  female         NaN         NaN
# 2500  NA21141  GIH       SAS  female         NaN         NaN
# 2501  NA21142  GIH       SAS  female         NaN         NaN
# 2502  NA21143  GIH       SAS  female         NaN         NaN
# 2503  NA21144  GIH       SAS  female         NaN         NaN
#
# [2504 rows x 6 columns]

# %% [markdown]
# # Merge PCA and population information

# %%
pcaped=pd.merge(pca,ped,right_on="sample",left_on="IID",how="inner")
pcaped
# Out:
#      #FID      IID  ALLELE_CT  NAMED_ALLELE_DOSAGE_SUM   PC1_AVG   PC2_AVG  \
# 0       0  HG00403     219504                   219504  0.000644 -0.029750
# 1       0  HG00404     219504                   219504 -0.000492 -0.031018
# 2       0  HG00406     219504                   219504  0.006210 -0.034375
# 3       0  HG00407     219504                   219504  0.006786 -0.023931
# 4       0  HG00409     219504                   219504 -0.002363 -0.023160
# ..    ...      ...        ...                      ...       ...       ...
# 499     0  NA19087     219504                   219504 -0.075155  0.030773
# 500     0  NA19088     219504                   219504 -0.079479  0.034983
# 501     0  NA19089     219504                   219504 -0.083754  0.037050
# 502     0  NA19090     219504                   219504 -0.069719  0.028421
# 503     0  NA19091     219504                   219504 -0.077385  0.038104
#
#       PC3_AVG   PC4_AVG   PC5_AVG   PC6_AVG   PC7_AVG   PC8_AVG   PC9_AVG  \
# 0   -0.015150 -0.012238  0.022915  0.023541 -0.033705 -0.007513 -0.012540
# 1   -0.007642 -0.020500  0.028407 -0.008724  0.012335 -0.004921 -0.005570
# 2   -0.008986 -0.003351 -0.021756 -0.018243  0.003339 -0.007606 -0.034002
# 3   -0.007044 -0.004661  0.009854  0.000890  0.006796 -0.020050 -0.013187
# 4    0.032066  0.014556  0.023677  0.007048  0.012859  0.031961 -0.013063
# ..        ...       ...       ...       ...       ...       ...       ...
# 499 -0.012063 -0.020874 -0.009061  0.016212 -0.014142 -0.009302 -0.033492
# 500 -0.023635 -0.018341 -0.006770 -0.019187 -0.020756 -0.020069 -0.000052
# 501 -0.021951  0.030121 -0.041074 -0.019957  0.002440 -0.010965  0.014069
# 502 -0.014476  0.012602 -0.032481 -0.032686  0.023443  0.004380  0.006470
# 503 -0.017811  0.021642 -0.035877 -0.028448 -0.002518 -0.011106  0.003426
#
#      PC10_AVG   sample  pop super_pop  gender  Unnamed: 4  Unnamed: 5
# 0    0.002717  HG00403  CHS       EAS    male         NaN         NaN
# 1    0.024897  HG00404  CHS       EAS  female         NaN         NaN
# 2    0.006411  HG00406  CHS       EAS    male         NaN         NaN
# 3    0.035033  HG00407  CHS       EAS  female         NaN         NaN
# 4    0.011022  HG00409  CHS       EAS    male         NaN         NaN
# ..        ...      ...  ...       ...     ...         ...         ...
# 499 -0.018796  NA19087  JPT       EAS  female         NaN         NaN
# 500  0.010113  NA19088  JPT       EAS    male         NaN         NaN
# 501  0.021758  NA19089  JPT       EAS    male         NaN         NaN
# 502 -0.018362  NA19090  JPT       EAS  female         NaN         NaN
# 503 -0.003905  NA19091  JPT       EAS    male         NaN         NaN
#
# [504 rows x 20 columns]

# %% [markdown]
# # Plotting

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=pcaped,x="PC1_AVG",y="PC2_AVG",hue="pop",s=50)
# Out:
# <AxesSubplot: xlabel='PC1_AVG', ylabel='PC2_AVG'>
